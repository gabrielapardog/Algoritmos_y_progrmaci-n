# %% [markdown]
# # Laboratorio 1

# %% [markdown]
# ## Desarrollo de una herramienta analítica usando recursos nativos de Python

# %% [markdown]
# Para el desarrollo de esta actividad debes utilizar únicamente recursos nativos de Python (puedes usar librerías como `math` y `random`). Está prohibido el uso de librerías externas, a excepción de `matplotlib`. Te recomendamos leer por completo el enunciado del laboratorio antes de comenzar, de forma que tengas claro el propósito global de la actividad y puedas desarrollar tu solución apuntando a él desde el inicio.

# %% [markdown]
# En algunas de las misiones encontrarás: una **versión base**, la cual indica el requerimiento mínimo de la misión; una **versión completa**, la cual indica mejoras deseables o complementos a la **versión base**. Un desarrollo aceptable del laboratorio debe satisfacer la **versión base** y un desarrollo correcto del laboratorio debe satisfacer la **versión completa**. Cumplir con el desarrollo de la **versión completa** desde un inicio hará más sencillas las misiones siguientes.

# %% [markdown]
# Al desarrollar este laboratorio pondrás a prueba tus habilidades para:
#
# 1. Identificar y abordar preguntas de negocio y de *analytics*.
# 2. Leer datos desde archivos y almacenarlos en estructuras de Python.
# 3. Crear y llamar funciones.
# 4. Implementar condicionales diferenciando `if`, `elif` y `else`.
# 5. Implementar ciclos diferenciando el propósito de `for` y `while`.

# %% [markdown]
# ## Contexto: exploración del potencial para asignar becas Unialpes

# %% [markdown]
# La Universidad ean se ha caracterizado por su compromiso con la generación de impacto en la sociedad a través de diferentes programas de becas. Programas como Becas para los Mejores, entre otros, han sido revolucionarios al permitir que estudiantes de bajos recursos puedan acceder a una de las universidades más prestigiosas del país.

# %% [markdown]
# Actualmente, la universidad quiere evaluar el potencial impacto que tendrían algunos programas de acción afirmativa para asignación de becas, con base en información demográfica que ha obtenido a través de encuestas a personas interesadas en becas. Se cuenta con información respecto a la edad, género, estado civil, estrato socioeconómico, región de proveniencia, desempeño académico y nivel de escolaridad de las personas encuestadas. Los encargados de diseñar el programa saben que utilizar criterios basados en este tipo de variables es un tema sensible, pero es necesario si se quieren focalizar las oportunidades en poblaciones menos representadas.

# %% [markdown]
# El objetivo de este laboratorio es crear una herramienta computacional que permita a un tomador de decisiones explorar qué efecto podría tener el uso de diferentes reglas para seleccionar a los beneficiarios de las becas. Puntualmente, se espera que, para distintas reglas de selección (ej., pertenecer a cierta región, rango de edad, etc.), la herramienta ofrezca una caracterización de los potenciales beneficiarios de las becas (a partir de estadísticas descriptivas y visualizaciones), de forma que exista un sustento para elegir la regla de selección adecuada.

# %% [markdown]
# ## Fase 1: obtener e inspeccionar archivos

# %% [markdown]
# Los datos de encuestas fueron obtenidos como parte de un trabajo de campo y, por limitaciones tecnológicas, solo se cuenta con la información en archivos de texto plano (`.txt`). Cada archivo corresponde a uno de los atributos antes mencionados y están estructurados de forma que todos relacionan a las personas encuestadas en el mismo orden (i.e., en cada archivo la primera línea corresponde a un dato de la primera persona encuestada, la segunda línea corresponde a un dato de la segunda persona encuestada, etc.).

# %% [markdown]
# Los archivos con los que cuentas son:
#
# * `"edad.txt"`: un archivo con la edad de cada persona encuestada;
# * `"escolaridad.txt"`: un archivo con el nivel de escolaridad de cada persona encuestada;
# * `"estado_civil.txt"`: un archivo con el estado civil de cada persona encuestada;
# * `"estrato.txt"`: un archivo con el estrato socioeconómico de cada persona encuestada;
# * `"genero.txt"`: un archivo con el género de cada persona encuestada;
# * `"promedio.txt"`: un archivo con el promedio académico de cada persona encuestada;
# * `"region.txt"`: un archivo con la región de proveniencia de cada persona encuestada.

# %% [markdown]
# ### Misión 1

# %% [markdown]
# **Versión base**: utiliza métodos de lectura de archivos para guardar la información de cada archivo en una estructura de datos de Python, de manera que se respete el orden y la categoría de los datos.

# %% [markdown]
# **Versión completa**: escribe una función que sea capaz de ejecutar la **versión base** y llámala dentro de un ciclo para automatizar la lectura de los archivos.

# %%
# Implementa tu respuesta en esta celda
contador = 0 ; numerodepersona = 1 ; contadorlistas = 0

listaedad = [36,66,24,55,26,69,79,54,51,80,30,64,40,47,24,76,65,38,37,71,51,51,33,24,71,78,75,38,49,49,53,62,26,67,68,70,57,47,30,44,22,30,64,21,54,35,52,27,20,
59,40,23,58,71,77,70,31,19,31,75,63,79,67,46,79,30,19,64,52,79,35,74,18,22,58,77,22,73,59,18,46,35,38,80,65,41,46,36,46,56,37,67,20,46,62,70,31,20,64,78,66,45,43,70,
43,24,58,62,60,80,73,73,57,42,51,52,58,39,43,66,32,49,44,57,39,21,27,31,28,44,80,71,33,22,78,60,70,62,45,78,78,42,21,44,38,19,31,58,69,34,69,80,20,59,29,33,29,44,55,
47,26,47,20,43,27,29,21,70,69,45,69,34,28,50,79,29,53,36,39,57,62,42,51,57,67,52,58,36,27,70,21,55,50,46,75,54,80,61,78,21,76,61,67,66,27,74,21,21,55,45,21,22,30,64,
78,52,61,19,53,43,66,34,43,70,27,53,40,32,33,63,69,22,58,23,44,65,20,39,54,24,54,50,59,20,19,19,36,48,59,25,74,36,57,66,60,56,48,68,60,50,30,36,78,75,36,80,48,74,47,
40,71,57,46,77,29,77,65,35,29,36,53,22,28,61,40,57,20,43,54,54,18,75,45,39,41,56,71,54,58,79,30,75,45,38,55,24,68,30,24,52,29,76,25,58,65,53,64,32,74,18,52,48,65,42,
77,31,63,35,48,71,48,70,57,32,45,68,23,26,37,34,27,49,57,42,67,70,59,29,20,42,18,48,41,77,68,79,49,24,24,23,73,27,32,80,39,74,47,44,54,46,77,55,34,74,21,69,69,62,35,
21,24,75,67,71,49,28,56,58,68,42,60,44,37,69,75,27,57,52,22,76,48,78,79,28,50,35,66,66,58,22,23,74,38,31,39,55,18,66,30,57,28,50,24,76,18,44,80,54,43,50,79,67,63,53,
71,19,38,53,65,20,45,25,75,66,25,24,33,43,66,33,46,53,36,50,76,80,74,64,22,41,20,75,54,72,38,24,67,32,50,35,21,54,64,29,29,38,47,27,73,26,69,35,70,25,19,80,60,39,76,
34,59,49,23,34,23,24,50,54,66,39,43]

Secundaria = "Secundaria" ; Profesional = "Profesional" ; Primaria = "Primaria"; Maestria = "Maestria"

listaescolaridad = [Secundaria,Profesional,Secundaria,Secundaria,Secundaria,Secundaria,Secundaria,Secundaria,Secundaria,
3.1,3.1,4.2,2.7,3.0,1.0,2.5,4.0,4.0,0.3,0.3,2.9,2.1,2.0,2.5,1.1,3.6,3.1,3.1,1.7,3.0,3.5,1.3,1.7,3.4,3.2,4.5,4.2,4.1,3.5,3.0,0.1,3.8,0.2,3.4,2.0,3.3,1.9,0.7,1.3,3.7,3.5,2.3,
2.7,3.4,4.9,3.7,1.8,2.4,3.2,0.6,3.4,4.6,3.2,2.2,2.2,3.5,2.2,1.4,0.1,3.1,0.2,3.3,3.7,2.0,4.9,3.4,0.8,2.4,2.1,2.9,2.1,2.7,3.0,3.2,2.6]

Region_1 = "Region_1" ; Region_2 = "Region_2" ; Region_3 = "Region_3" ; Region_4 = "Region_4" ; Region_5 = "Region_5" ; 

listaregion = [Region_1,Region_1,Region_2,Region_2,Region_3,Region_4,Region_5,Region_1,Region_4,Region_1,Region_4,Region_2,Region_4,Region_2,Region_2,Region_2,Region_4,
Region_4,Region_1,Region_1,Region_2,Region_2,Region_4,Region_4,Region_1,Region_4,Region_1,Region_4,Region_4,Region_1,Region_4,Region_4,Region_4,Region_1,Region_1,Region_2,
Region_4,Region_4,Region_4,Region_3,Region_2,Region_2,Region_4,Region_2,Region_3,Region_1,Region_1,Region_4,Region_4,Region_5,Region_3,Region_4,Region_2,Region_4,Region_2,
Region_2,Region_4,Region_4,Region_3,Region_4,Region_4,Region_1,Region_1,Region_1,Region_2,Region_3,Region_2,Region_2,Region_2,Region_2,Region_4,Region_4,Region_4,Region_3,
Region_1,Region_1,Region_2,Region_4,Region_4,Region_2,Region_4,Region_2,Region_4,Region_5,Region_4,Region_4,Region_4,Region_4,Region_4,Region_4,Region_4,Region_1,Region_1,
Region_1,Region_1,Region_2,Region_4,Region_5,Region_3,Region_3,Region_1,Region_2,Region_5,Region_2,Region_4,Region_4,Region_2,Region_2,Region_4,Region_2,Region_1,Region_1,
Region_1,Region_3,Region_4,Region_1,Region_1,Region_3,Region_4,Region_4,Region_4,Region_2,Region_4,Region_4,Region_4,Region_4,Region_3,Region_4,Region_4,Region_3,Region_1,
Region_2,Region_4,Region_2,Region_1,Region_4,Region_4,Region_1,Region_3,Region_4,Region_1,Region_4,Region_4,Region_4,Region_1,Region_4,Region_1,Region_1,Region_1,Region_1,
Region_1,Region_2,Region_1,Region_3,Region_1,Region_4,Region_4,Region_4,Region_2,Region_4,Region_2,Region_2,Region_1,Region_1,Region_4,Region_2,Region_2,Region_2,Region_4,
Region_4,Region_1,Region_4,Region_2,Region_2,Region_4,Region_1,Region_2,Region_4,Region_2,Region_2,Region_4,Region_4,Region_1,Region_1,Region_2,Region_1,Region_1,Region_4,
Region_2,Region_3,Region_4,Region_2,Region_2,Region_4,Region_3,Region_5,Region_4,Region_4,Region_3,Region_4,Region_2,Region_1,Region_4,Region_1,Region_4,Region_3,Region_1,
Region_1,Region_4,Region_1,Region_1,Region_4,Region_1,Region_4,Region_3,Region_4,Region_2,Region_2,Region_4,Region_4,Region_5,Region_3,Region_1,Region_4,Region_1,Region_4,
Region_4,Region_1,Region_3,Region_4,Region_1,Region_2,Region_4,Region_1,Region_2,Region_4,Region_1,Region_4,Region_4,Region_4,Region_2,Region_5,Region_4,Region_4,Region_1,
Region_4,Region_2,Region_1,Region_2,Region_1,Region_2,Region_2,Region_2,Region_2,Region_4,Region_4,Region_4,Region_2,Region_1,Region_1,Region_1,Region_3,Region_2,Region_4,
Region_1,Region_4,Region_1,Region_2,Region_1,Region_4,Region_2,Region_1,Region_4,Region_1,Region_4,Region_1,Region_4,Region_3,Region_2,Region_4,Region_5,Region_1,Region_1,
Region_1,Region_4,Region_1,Region_3,Region_2,Region_1,Region_2,Region_2,Region_4,Region_4,Region_4,Region_2,Region_4,Region_4,Region_4,Region_2,Region_4,Region_2,Region_5,
Region_1,Region_3,Region_1,Region_1,Region_3,Region_2,Region_4,Region_2,Region_4,Region_1,Region_2,Region_2,Region_1,Region_4,Region_4,Region_2,Region_4,Region_4,Region_3,
Region_1,Region_3,Region_4,Region_2,Region_2,Region_4,Region_1,Region_4,Region_1,Region_1,Region_4,Region_2,Region_4,Region_4,Region_4,Region_1,Region_2,Region_1,Region_1,
Region_4,Region_4,Region_3,Region_2,Region_1,Region_2,Region_4,Region_2,Region_1,Region_1,Region_4,Region_4,Region_4,Region_4,Region_4,Region_2,Region_1,Region_4,Region_1,
Region_1,Region_2,Region_2,Region_4,Region_2,Region_3,Region_4,Region_1,Region_4,Region_2,Region_4,Region_2,Region_2,Region_4,Region_1,Region_1,Region_5,Region_2,Region_4,
Region_1,Region_4,Region_4,Region_1,Region_2,Region_4,Region_2,Region_2,Region_2,Region_1,Region_1,Region_1,Region_1,Region_2,Region_1,Region_1,Region_1,Region_1,Region_2,
Region_2,Region_1,Region_4,Region_1,Region_4,Region_2,Region_2,Region_1,Region_1,Region_2,Region_1,Region_4,Region_1,Region_3,Region_2,Region_1,Region_4,Region_4,Region_4,
Region_1,Region_5,Region_2,Region_4,Region_1,Region_1,Region_3,Region_4,Region_1,Region_2,Region_2,Region_1,Region_1,Region_2,Region_2,Region_1,Region_4,Region_4,Region_4,
Region_4,Region_4,Region_4,Region_4,Region_4,Region_2,Region_1,Region_4,Region_4,Region_1,Region_1,Region_4,Region_1,Region_4,Region_2,Region_4,Region_1,Region_1,Region_4,
Region_4,Region_4,Region_5,Region_2,Region_1,Region_1,Region_4,Region_4,Region_4,Region_2,Region_4,Region_1,Region_4,Region_4,Region_4,Region_4,Region_4,Region_2,Region_2,
Region_4,Region_4,Region_4,Region_1,Region_4,Region_5,Region_4,Region_1,Region_2,Region_4,Region_1,Region_2,Region_4,Region_1,Region_2,Region_5,Region_4,Region_1,Region_4,
Region_1,Region_1,Region_4,Region_4,Region_1,Region_1,Region_1,Region_2,Region_4,Region_4]

while contador <= 499:

    print (numerodepersona , "," , listaedad[contadorlistas] , "," , listaescolaridad[contadorlistas] , "," , listaestadocivil[contadorlistas] , "," , listaestrato[contadorlistas] ,  "," , listagenero[contadorlistas] , ",", listaregion[contadorlistas] , "," , 
    listapromedio[contadorlistas])
    numerodepersona += 1
    contadorlistas += 1
    contador += 1
# Out:
# 1 , 36 , Secundaria , casada , 5 , masculino , Region_1 , 2.4
# 2 , 66 , Profesional , divorciada , 1 , masculino , Region_1 , 0.9
# 3 , 24 , Secundaria , divorciada , 3 , femenino , Region_2 , 3.2
# 4 , 55 , Secundaria , casada , 3 , masculino , Region_2 , 2.1
# 5 , 26 , Secundaria , divorciada , 2 , otro , Region_3 , 2.1
# 6 , 69 , Secundaria , divorciada , 3 , no binario , Region_4 , 2.0
# 7 , 79 , Secundaria , casada , 4 , masculino , Region_5 , 2.7
# 8 , 54 , Secundaria , casada , 2 , femenino , Region_1 , 4.9
# 9 , 51 , Secundaria , soltera , 2 , femenino , Region_4 , 2.1
# 10 , 80 , Profesional , soltera , 3 , masculino , Region_1 , 4.5
# 11 , 30 , Secundaria , soltera , 2 , femenino , Region_4 , 3.0
# 12 , 64 , Primaria , casada , 2 , femenino , Region_2 , 3.0
# 13 , 40 , Secundaria , casada , 2 , femenino , Region_4 , 3.5
# 14 , 47 , Secundaria , casada , 3 , femenino , Region_2 , 1.8
# 15 , 24 , Secundaria , divorciada , 1 , no binario , Region_2 , 1.2
# ...

# %% [markdown]
# ### Misión 2

# %% [markdown]
# **Versión base**: calcula estadísticas descriptivas básicas (por lo menos, media/mediana y varianza/desviación) para cada variable relevante en el contexto del problema y repórtalas concluyendo acerca de las principales características de los datos.

# %% [markdown]
# **Versión completa**: complementa la **versión base** con visualizaciones informativas sobre los datos (ej., histogramas, gráficos de dispersión, boxplots, etc.), relevantes para el problema.

# %%
# Implementa tu respuesta en esta celda
# Out:
# Numero de filas = 500
# promedio = 48.748
# mediana = 49.0
# varianza = 345.76849599999997
# desviacion estandar = 18.59485133040864
# rango = 62
# Edad None
#
# Numero de filas = 500
# promedio = 2.308
# mediana = 25.5
# varianza = 0.9531359999999962
# desviacion estandar = 0.9762868430947926
# rango = 4
# Estrato None
#
# Numero de filas = 500
# promedio = 2.6212000000000004
# mediana = 25.85
# varianza = 1.2452705600000027
# desviacion estandar = 1.1159169144698913
# rango = 5.0
# promedio None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-e57c2e48aa15> in <module>
#      41 print("promedio",descriptive_stadistic(promedio))
#      42 #histograma
# ---> 43 plt.hist(edad)
#      44 plt.show()
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/_api/__init__.py in __getattr__(name)
#     221             return props[name].__get__(instance)
# ...

# %% [markdown]
# ## Referencias

# %% [markdown]
# * Discriminación Positiva<br>
# https://es.wikipedia.org/wiki/Discriminaci%C3%B3n_positiva
# * Análisis de formulación del programa “Ser Pilo Paga”<br>
# https://repository.urosario.edu.co/handle/10336/12526
# * La acción afirmativa en la Universidad de los Andes: El caso del programa "Oportunidades para talentos nacionales"<br> http://www.scielo.org.co/scielo.php?script=sci_arttext&pid=S0123-885X2004000300005
# * Acción afirmativa y equidad: un análisis desde la propuesta de Thomas Nagel<br>
# http://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S2007-24062016000200049

# %% [markdown]
# ## Créditos

# %% [markdown]
# __Autores__: Camilo Hernando Gómez Castro, Alejandro Mantilla Redondo, Diego Alejandro Cely Gómez.
#
# __Fecha última actualización__: 11/07/2022
